# %%
## Sravanthi Data Science Masters Assignment 8, Session 8 PANDAS Q2 Create a DatetimeIndex that contains each business day of 2015& index series of random nos

import pandas as pd
import numpy as np

dti = pd.date_range(start='2015-01-01', end='2015-12-31', freq='B') 
s = pd.Series(np.random.rand(len(dti)), index=dti)
print(s)
# Out:
# 2015-01-01    0.661162
# 2015-01-02    0.930421
# 2015-01-05    0.240556
# 2015-01-06    0.099084
# 2015-01-07    0.037455
# 2015-01-08    0.102912
# 2015-01-09    0.384099
# 2015-01-12    0.756024
# 2015-01-13    0.876016
# 2015-01-14    0.061728
# 2015-01-15    0.437637
# 2015-01-16    0.187137
# 2015-01-19    0.075200
# 2015-01-20    0.274903
# 2015-01-21    0.740124
# 2015-01-22    0.596384
# 2015-01-23    0.598444
# 2015-01-26    0.233177
# 2015-01-27    0.399297
# 2015-01-28    0.846159
# 2015-01-29    0.916862
# 2015-01-30    0.718356
# 2015-02-02    0.183352
# 2015-02-03    0.268747
# 2015-02-04    0.948754
# 2015-02-05    0.862106
# 2015-02-06    0.286688
# 2015-02-09    0.306704
# 2015-02-10    0.132499
# 2015-02-11    0.320857
#                 ...
# 2015-11-20    0.237760
# 2015-11-23    0.300907
# 2015-11-24    0.982198
# 2015-11-25    0.722122
# 2015-11-26    0.548355
# 2015-11-27    0.361247
# 2015-11-30    0.187496
# 2015-12-01    0.065449
# 2015-12-02    0.078141
# ...
